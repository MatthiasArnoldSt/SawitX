# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/User/Desktop/SEM 7/FYP I/Dataset/USD_MYR Historical Data.csv')

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

df.to_excel('formatted_output.xlsx', index=False)

# %%
df = pd.read_csv("C:/Users/User/Desktop/SEM 7/FYP I/Dataset/Palm Oil Futures Historical Data.csv")

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

df.to_excel('formatted_PalmOilFutures.xlsx', index=False)

# %%
df = pd.read_csv("C:/Users/User/Desktop/SEM 7/FYP I/Dataset/US Soybean Oil Futures Historical Data.csv")

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

df.to_excel('formatted_Soybean.xlsx', index=False)
